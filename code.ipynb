# %%
str ="1234567"
print (str)
print (str[1:5])
print (str*2)
print(str+"TEST")
# Out:
# 1234567
# 2345
# 12345671234567
# 1234567TEST

# %% [markdown]
# **List**

# %%
list1 =["123","234","345 ","456","567"]
list2 =["abc","bcd","cde ","def","efg"]
print (list1)
print (list1[1:3])
print (list1*2)
print(list1+list2)
print(list1[-3:-1])
# Out:
# ['123', '234', '345 ', '456', '567']
# ['234', '345 ']
# ['123', '234', '345 ', '456', '567', '123', '234', '345 ', '456', '567']
# ['123', '234', '345 ', '456', '567', 'abc', 'bcd', 'cde ', 'def', 'efg']
# ['345 ', '456']

# %%
list2.append("fgh")
print(list2)
del list1[0]
print(list1)
l=len(list2)
print(l)
list3 = list1 + list2
for i in range(len(list3)):
    print(list3[i])
# Out:
# ['abc', 'bcd', 'cde ', 'def', 'efg', 'fgh', 'fgh', 'fgh', 'fgh', 'fgh', 'fgh']
# ['567']
# 11
# 567
# abc
# bcd
# cde
# def
# efg
# fgh
# fgh
# fgh
# fgh
# fgh
# fgh

# %% [markdown]
# *元组tuple 不可改变内容的list*

# %%
tuple = ( 'runoob', 786 , 2.23, 'john', 70.2 )
tinytuple = (123, 'john')
 
print (tuple)               # 输出完整元组
print (tuple[0]  )          # 输出元组的第一个元素
print (tuple[1:3]  )        # 输出第二个至第四个（不包含）的元素 
print (tuple[2:]   )        # 输出从第三个开始至列表末尾的所有元素
print (tinytuple * 2    )   # 输出元组两次
print (tuple + tinytuple )  # 打印组合的元组
# Out:
# ('runoob', 786, 2.23, 'john', 70.2)
# runoob
# (786, 2.23)
# (2.23, 'john', 70.2)
# (123, 'john', 123, 'john')
# ('runoob', 786, 2.23, 'john', 70.2, 123, 'john')

# %% [markdown]
# *字典(dictionary)是除列表以外python之中最灵活的内置数据结构类型。列表是有序的对象集合，字典是无序的对象集合。
#
# 两者之间的区别在于：字典当中的元素是通过键来存取的，而不是通过偏移存取。
#
# 字典用"{ }"标识。字典由索引(key)和它对应的值value组成*

# %%
#字典dict 健值对 用健来唯一索引值
dict = {}
dict['one'] = "This is one"
dict[2] = "This is two"
tinydict ={'name':'runoob','code':6734,'dept':'sales'}

print(dict['one'])
print(dict[2])
print(tinydict)
print(tinydict.keys())
print(tinydict.values())
# Out:
# This is one
# This is two
# {'name': 'runoob', 'code': 6734, 'dept': 'sales'}
# dict_keys(['name', 'code', 'dept'])
# dict_values(['runoob', 6734, 'sales'])

# %%
del dict ['one']

print (dict)
# Out:
# {2: 'This is two'}

# %% [markdown]
# *运算符*

# %%
a = 23
b = 5
c= 0

c = a + b
print("1 - c 的值为：", c)

c= a - b
print("2 - c 的值为：", c)

c =a * b
print("3 - c 的值为：", c)

c = a / b
print("4 - c 的值为：", c)

c = a % b
print("5 - c 的值为：", c)

a = 2
b = 3
c = a ** b
print("6 - c 的值为：", c)

a = 10
b = 5
c = a // b
print("7 - c 的值为：", c)
# Out:
# 1 - c 的值为： 28
# 2 - c 的值为： 18
# 3 - c 的值为： 115
# 4 - c 的值为： 4.6
# 5 - c 的值为： 3
# 6 - c 的值为： 8
# 7 - c 的值为： 2

# %%
a = 21
b = 10
c = 2
c %= a #取摸
print("1 - c 的值为：", c)
 
c **= a#指数
print("2 - c 的值为：", c)
 
c //= a#整除
print("3 - c 的值为：", c)
# Out:
# 1 - c 的值为： 2
# 2 - c 的值为： 2097152
# 3 - c 的值为： 99864

# %%
a=60
b=13
c=0

c=a&b
print("1 - c 的值为：", c) 
c=a|b
print("2 - c 的值为：", c)
c=a^b
print("3 - c 的值为：", c)
c=~a
print("4 - c 的值为：", c)
c=a<<2
print("5 - c 的值为：", c)
c=a>>2
print("6 - c 的值为：", c)
# Out:
# 1 - c 的值为： 12
# 2 - c 的值为： 61
# 3 - c 的值为： 49
# 4 - c 的值为： -61
# 5 - c 的值为： 240
# 6 - c 的值为： 15

# %% [markdown]
# *条件语句*

# %%
date = 200

if date <= 5:
    print("工作日")
elif date == 6 or date == 7:
    print("周末")
else:
    print("wrong")
# Out:
# wrong

# %% [markdown]
# *循环语句*

# %%
num = 9
while num > 0:
    print("num 的值为：", num)
    num-=1
else :
    print("num 小于或等于 0")
print("end")
# Out:
# num 的值为： 9
# num 的值为： 8
# num 的值为： 7
# num 的值为： 6
# num 的值为： 5
# num 的值为： 4
# num 的值为： 3
# num 的值为： 2
# num 的值为： 1
# num 小于或等于 0
# end

# %%
for letter in 'Python':
    print("当前字母：%s"%letter)

fruits = ['banana','apple','mango']
for fruit in fruits:
    print("当前水果味为:%s"%fruit)
# Out:
# 当前字母：P
# 当前字母：y
# 当前字母：t
# 当前字母：h
# 当前字母：o
# 当前字母：n
# 当前水果味为:banana
# 当前水果味为:apple
# 当前水果味为:mango

# %%
for index in range (len(fruits)):
    print("当前水果为:%s"%fruits[index])
# Out:
# 当前水果为:banana
# 当前水果为:apple
# 当前水果为:mango

# %%
i =2 
while i < 100:
    j =2 
    while (j <= (i/j)):
        if not(i%j): break
        j = j + 1
    if(j > i/j):print (i,"是素数")
    i +=1
# Out:
# 2 是素数
# 3 是素数
# 5 是素数
# 7 是素数
# 11 是素数
# 13 是素数
# 17 是素数
# 19 是素数
# 23 是素数
# 29 是素数
# 31 是素数
# 37 是素数
# 41 是素数
# 43 是素数
# 47 是素数
# 53 是素数
# 59 是素数
# 61 是素数
# 67 是素数
# 71 是素数
# 73 是素数
# 79 是素数
# 83 是素数
# 89 是素数
# 97 是素数

# %%
varl = "hello "
varl2 = "world"
print(varl+varl2)
# Out:
# hello world

# %%
x = 23
name = "yn"
print("我的名字是%s,我的年龄是%d"%(name,x))
# Out:
# 我的名字是yn,我的年龄是23

# %%
str = input("请输入：")
print("你输入的内容是: ", str)
# Out:
# 你输入的内容是:  123
